# %% [markdown]
# - After sucesfull installation of libraries and other stuff, lets move to other parts for the practice

# %% [markdown]
# ## 01- Object Creation

# %%
import numpy as np
import pandas as pd

a= pd.Series([1,2,3,100,200,300])
a
# Out:
# 0      1
# 1      2
# 2      3
# 3    100
# 4    200
# 5    300
# dtype: int64

# %%
# we can also add an Empty cell in the series : for an empty cell we need to command "np.nan"
a1=pd.Series([1,3,5,100,np.nan,3.5,1001])
a1
# Out:
# 0       1.0
# 1       3.0
# 2       5.0
# 3     100.0
# 4       NaN
# 5       3.5
# 6    1001.0
# dtype: float64

# %% [markdown]
# - We can also create objects for the Dates

# %%
tarekh= pd.date_range("20220101",periods=7)
tarekh
# Out:
# DatetimeIndex(['2022-01-01', '2022-01-02', '2022-01-03', '2022-01-04',
#                '2022-01-05', '2022-01-06', '2022-01-07'],
#               dtype='datetime64[ns]', freq='D')

# %%
tarekh= pd.date_range("20220101",periods=10)
tarekh
# Out:
# DatetimeIndex(['2022-01-01', '2022-01-02', '2022-01-03', '2022-01-04',
#                '2022-01-05', '2022-01-06', '2022-01-07', '2022-01-08',
#                '2022-01-09', '2022-01-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
tarekh= pd.date_range("20220101",periods=15)
tarekh
# Out:
# DatetimeIndex(['2022-01-01', '2022-01-02', '2022-01-03', '2022-01-04',
#                '2022-01-05', '2022-01-06', '2022-01-07', '2022-01-08',
#                '2022-01-09', '2022-01-10', '2022-01-11', '2022-01-12',
#                '2022-01-13', '2022-01-14', '2022-01-15'],
#               dtype='datetime64[ns]', freq='D')

# %% [markdown]
# ##### Using the above mentioned dates series, we can convert it into a data frame

# %%
df=pd.DataFrame(np.random.randn(20,4), index=tarekh, columns=list("ABCD"))
df
# Out:
#                    A         B         C         D
# 2022-01-01  0.102043 -1.449566  1.697798 -0.119414
# 2022-01-02 -0.454811  0.530081  0.268174 -2.590615
# 2022-01-03 -0.785923  0.018957 -0.347668  1.555676
# 2022-01-04 -2.541553 -0.319854 -0.666238 -0.012229
# 2022-01-05  0.231044 -0.531193  0.353065 -0.313550
# 2022-01-06 -0.787830 -0.582744  0.658885  1.246843
# 2022-01-07  0.589287  0.250074 -0.150527  1.477540
# 2022-01-08 -0.291630  0.173263  0.625967  1.300815
# 2022-01-09  0.619184 -0.336175 -0.357134  0.653001
# 2022-01-10 -0.212093  0.310808 -0.356398  1.059319
# 2022-01-11 -0.039335 -1.283406 -0.169316 -0.443669
# 2022-01-12 -2.496872 -0.156115 -1.242639 -0.185344
# 2022-01-13 -1.478609 -1.763715  0.081166 -0.286686
# 2022-01-14 -0.429221  0.412335  0.671963 -0.094793
# 2022-01-15 -0.676340  0.901447 -0.824043  2.096372
# 2022-01-16  0.223298 -0.203682  2.209086 -1.704479
# 2022-01-17  1.279543 -1.550134  1.174299  1.710094
# ...

# %%
df2=pd.DataFrame(
    {"A":1.0, "B":pd.Timestamp("20220101"),
    "C":pd.Series(1, index=list(range(4)),dtype="float32"),
    "D":np.array([3] * 4,dtype="int32"),
    "E":pd.Categorical(["test","train","test","train"]),"F":"foo",
    }
)
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2022-01-01  1.0  3   test  foo
# 1  1.0 2022-01-01  1.0  3  train  foo
# 2  1.0 2022-01-01  1.0  3   test  foo
# 3  1.0 2022-01-01  1.0  3  train  foo

# %%
df2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %% [markdown]
# ## 2- Data Viewing

# %%
# how to view the data 
# we can view the data in two forms :
# by using data.head() or data.tail() methods:
df2.head() # by using tyhis method we can actually see the first few rows "max 5 rows"
# Out:
#      A          B    C  D      E        F
# 0  1.0 2022-01-01  1.0  3   Girl  Females
# 1  1.0 2022-01-01  1.0  3  Women  Females
# 2  1.0 2022-01-01  1.0  3   Girl  Females
# 3  1.0 2022-01-01  1.0  3  Women  Females

# %%
df2.head(3)
# Out:
#      A          B    C  D      E        F
# 0  1.0 2022-01-01  1.0  3   Girl  Females
# 1  1.0 2022-01-01  1.0  3  Women  Females
# 2  1.0 2022-01-01  1.0  3   Girl  Females

# %%
# by using tail method, by using this method we can actually see the last rows of the data 
df2.tail()
# Out:
#      A          B    C  D      E        F
# 0  1.0 2022-01-01  1.0  3   Girl  Females
# 1  1.0 2022-01-01  1.0  3  Women  Females
# 2  1.0 2022-01-01  1.0  3   Girl  Females
# 3  1.0 2022-01-01  1.0  3  Women  Females

# %%
df2.tail(1) # so by using these two methods we can see the data's head and the tail (start or akhri wali rows)
# Out:
#      A          B    C  D      E        F
# 3  1.0 2022-01-01  1.0  3  Women  Females

# %% [markdown]
# #### If we need to find the index of the data then we will use index formula, (row ka head is called index)

# %%
df
# Out:
#        Col1      Col2      Col3  X  Y
# 0  0.076200 -0.566446  0.036142  A  A
# 1 -2.074978  0.247792 -0.897157  A  B
# 2 -0.136795  0.018289  0.755414  A  A
# 3  0.215269  0.841009 -1.445810  A  B
# 4 -1.401973 -0.100918 -0.548242  A  A
# 5 -0.144620  0.354020 -0.035513  B  B
# 6  0.565738  1.545659 -0.974236  B  A
# 7 -0.070345  0.307969 -0.208499  B  B
# 8  1.033801 -2.400454  2.030604  B  A
# 9 -1.142631  0.211883  0.704721  B  B

# %%
df2
# Out:
#      A          B    C  D      E        F
# 0  1.0 2022-01-01  1.0  3   Girl  Females
# 1  1.0 2022-01-01  1.0  3  Women  Females
# 2  1.0 2022-01-01  1.0  3   Girl  Females
# 3  1.0 2022-01-01  1.0  3  Women  Females

# %%
df2.index
# Out:
# Int64Index([0, 1, 2, 3], dtype='int64')

# %% [markdown]
# ### 3- Conversion of dataframe into Numpy(array)

# %%
df.to_numpy()
# Out:
# array([[0.07619958783723642, -0.5664459304649568, 0.036141936684072715,
#         'A', 'A'],
#        [-2.0749776006900293, 0.24779219974854666, -0.8971567844396987,
#         'A', 'B'],
#        [-0.1367948332613474, 0.018289191349219306, 0.7554139823981354,
#         'A', 'A'],
#        [0.2152685809694434, 0.841008794931391, -1.4458100770443063, 'A',
#         'B'],
#        [-1.4019732815008439, -0.10091819994891389, -0.5482424491868549,
#         'A', 'A'],
#        [-0.14461950836938436, 0.35402033219923795, -0.03551302527814021,
#         'B', 'B'],
#        [0.5657383060625951, 1.5456588046255575, -0.9742363337673154, 'B',
#         'A'],
#        [-0.07034487710410242, 0.30796885521603423, -0.20849876310587975,
#         'B', 'B'],
#        [1.0338007325554992, -2.4004536338122957, 2.0306036208387996, 'B',
#         'A'],
#        [-1.1426312890227635, 0.21188338677770105, 0.7047206243171088,
#         'B', 'B']], dtype=object)

# %%
df2.to_numpy()
# Out:
# array([[1.0, Timestamp('2022-01-01 00:00:00'), 1.0, 3, 'Girl', 'Females'],
#        [1.0, Timestamp('2022-01-01 00:00:00'), 1.0, 3, 'Women',
#         'Females'],
#        [1.0, Timestamp('2022-01-01 00:00:00'), 1.0, 3, 'Girl', 'Females'],
#        [1.0, Timestamp('2022-01-01 00:00:00'), 1.0, 3, 'Women',
#         'Females']], dtype=object)

# %% [markdown]
# ####  4- We can check the Mean,Median and other Statistical functions by using only one method:

# %%
df.describe()
# Out:
#             Col1       Col2       Col3
# count  10.000000  10.000000  10.000000
# mean   -0.308033   0.045880  -0.058258
# std     0.949465   1.027150   1.019133
# min    -2.074978  -2.400454  -1.445810
# 25%    -0.893128  -0.071116  -0.809928
# 50%    -0.103570   0.229838  -0.122006
# 75%     0.180501   0.342507   0.537576
# max     1.033801   1.545659   2.030604

# %%
# now we can also transpose the data, like conversion of rows into column and column into rows
df.T
# Out:
#              0         1         2         3         4         5         6  \
# Col1    0.0762 -2.074978 -0.136795  0.215269 -1.401973  -0.14462  0.565738
# Col2 -0.566446  0.247792  0.018289  0.841009 -0.100918   0.35402  1.545659
# Col3  0.036142 -0.897157  0.755414  -1.44581 -0.548242 -0.035513 -0.974236
# X            A         A         A         A         A         B         B
# Y            A         B         A         B         A         B         A
#
#              7         8         9
# Col1 -0.070345  1.033801 -1.142631
# Col2  0.307969 -2.400454  0.211883
# Col3 -0.208499  2.030604  0.704721
# X            B         B         B
# Y            B         A         B

# %%
df2.T
# Out:
#                      0                    1                    2  \
# A                  1.0                  1.0                  1.0
# B  2022-01-01 00:00:00  2022-01-01 00:00:00  2022-01-01 00:00:00
# C                  1.0                  1.0                  1.0
# D                    3                    3                    3
# E                 Girl                Women                 Girl
# F              Females              Females              Females
#
#                      3
# A                  1.0
# B  2022-01-01 00:00:00
# C                  1.0
# D                    3
# E                Women
# F              Females

# %%
# or we can also write transpose :
df.transpose()
# Out:
#              0         1         2         3         4         5         6  \
# Col1    0.0762 -2.074978 -0.136795  0.215269 -1.401973  -0.14462  0.565738
# Col2 -0.566446  0.247792  0.018289  0.841009 -0.100918   0.35402  1.545659
# Col3  0.036142 -0.897157  0.755414  -1.44581 -0.548242 -0.035513 -0.974236
# X            A         A         A         A         A         B         B
# Y            A         B         A         B         A         B         A
#
#              7         8         9
# Col1 -0.070345  1.033801 -1.142631
# Col2  0.307969 -2.400454  0.211883
# Col3 -0.208499  2.030604  0.704721
# X            B         B         B
# Y            B         A         B

# %%
df2.transpose
# Out:
# <bound method DataFrame.transpose of      A          B    C  D      E        F
# 0  1.0 2022-01-01  1.0  3   Girl  Females
# 1  1.0 2022-01-01  1.0  3  Women  Females
# 2  1.0 2022-01-01  1.0  3   Girl  Females
# 3  1.0 2022-01-01  1.0  3  Women  Females>

# %% [markdown]
# #### 5- Arranging the data into ascending or Descending form:

# %%
df.sort_index(axis=1,ascending=True)
# Out:
#        Col1      Col2      Col3  X  Y
# 0  0.076200 -0.566446  0.036142  A  A
# 1 -2.074978  0.247792 -0.897157  A  B
# 2 -0.136795  0.018289  0.755414  A  A
# 3  0.215269  0.841009 -1.445810  A  B
# 4 -1.401973 -0.100918 -0.548242  A  A
# 5 -0.144620  0.354020 -0.035513  B  B
# 6  0.565738  1.545659 -0.974236  B  A
# 7 -0.070345  0.307969 -0.208499  B  B
# 8  1.033801 -2.400454  2.030604  B  A
# 9 -1.142631  0.211883  0.704721  B  B

# %%
df.sort_index(axis=1,ascending=False)
# Out:
#    Y  X      Col3      Col2      Col1
# 0  A  A  0.036142 -0.566446  0.076200
# 1  B  A -0.897157  0.247792 -2.074978
# 2  A  A  0.755414  0.018289 -0.136795
# 3  B  A -1.445810  0.841009  0.215269
# 4  A  A -0.548242 -0.100918 -1.401973
# 5  B  B -0.035513  0.354020 -0.144620
# 6  A  B -0.974236  1.545659  0.565738
# 7  B  B -0.208499  0.307969 -0.070345
# 8  A  B  2.030604 -2.400454  1.033801
# 9  B  B  0.704721  0.211883 -1.142631

# %%
# now if we want to sort/arrange the data with respect to only one Column then:
df.sort_values(by="Col1")
# Out:
#        Col1      Col2      Col3  X  Y
# 1 -2.074978  0.247792 -0.897157  A  B
# 4 -1.401973 -0.100918 -0.548242  A  A
# 9 -1.142631  0.211883  0.704721  B  B
# 5 -0.144620  0.354020 -0.035513  B  B
# 2 -0.136795  0.018289  0.755414  A  A
# 7 -0.070345  0.307969 -0.208499  B  B
# 0  0.076200 -0.566446  0.036142  A  A
# 3  0.215269  0.841009 -1.445810  A  B
# 6  0.565738  1.545659 -0.974236  B  A
# 8  1.033801 -2.400454  2.030604  B  A

# %%
df.sort_values(by="Y")
# Out:
#        Col1      Col2      Col3  X  Y
# 0  0.076200 -0.566446  0.036142  A  A
# 2 -0.136795  0.018289  0.755414  A  A
# 4 -1.401973 -0.100918 -0.548242  A  A
# 6  0.565738  1.545659 -0.974236  B  A
# 8  1.033801 -2.400454  2.030604  B  A
# 1 -2.074978  0.247792 -0.897157  A  B
# 3  0.215269  0.841009 -1.445810  A  B
# 5 -0.144620  0.354020 -0.035513  B  B
# 7 -0.070345  0.307969 -0.208499  B  B
# 9 -1.142631  0.211883  0.704721  B  B

# %%
## now we can also choose our values according to a specific Column :

# %%
df["Col2"]
# Out:
# 0   -0.566446
# 1    0.247792
# 2    0.018289
# 3    0.841009
# 4   -0.100918
# 5    0.354020
# 6    1.545659
# 7    0.307969
# 8   -2.400454
# 9    0.211883
# Name: Col2, dtype: float64

# %%
df["X"]
# Out:
# 0    A
# 1    A
# 2    A
# 3    A
# 4    A
# 5    B
# 6    B
# 7    B
# 8    B
# 9    B
# Name: X, dtype: object

# %%
df2
# Out:
#      A          B    C  D      E        F
# 0  1.0 2022-01-01  1.0  3   Girl  Females
# 1  1.0 2022-01-01  1.0  3  Women  Females
# 2  1.0 2022-01-01  1.0  3   Girl  Females
# 3  1.0 2022-01-01  1.0  3  Women  Females

# %%
df2["E"]
# Out:
# 0     Girl
# 1    Women
# 2     Girl
# 3    Women
# Name: E, dtype: category
# Categories (2, object): ['Girl', 'Women']

# %%
df2
# Out:
#      A          B    C  D      E        F
# 0  1.0 2022-01-01  1.0  3   Girl  Females
# 1  1.0 2022-01-01  1.0  3  Women  Females
# 2  1.0 2022-01-01  1.0  3   Girl  Females
# 3  1.0 2022-01-01  1.0  3  Women  Females

# %%
df2[0:2]
# Out:
#      A          B    C  D      E        F
# 0  1.0 2022-01-01  1.0  3   Girl  Females
# 1  1.0 2022-01-01  1.0  3  Women  Females

# %%
df2[0:1]
# Out:
#      A          B    C  D     E        F
# 0  1.0 2022-01-01  1.0  3  Girl  Females

# %%
df2[0:10]
# Out:
#      A          B    C  D      E        F
# 0  1.0 2022-01-01  1.0  3   Girl  Females
# 1  1.0 2022-01-01  1.0  3  Women  Females
# 2  1.0 2022-01-01  1.0  3   Girl  Females
# 3  1.0 2022-01-01  1.0  3  Women  Females

# %%
df=pd.DataFrame(np.random.randn(10,8), index=tarekh, columns=list("ABCDEFGH"))
df
# Out:
#                    A         B         C         D         E         F  \
# 2022-01-01  1.552807 -1.149299  0.188531  0.988964 -1.586136 -0.472381
# 2022-01-02  1.611722  0.566730 -0.641177  1.538774  0.309664 -0.448849
# 2022-01-03 -1.462225  1.850810  1.700770  0.353391  0.336489  1.057105
# 2022-01-04 -0.714745  0.804346  1.191655 -0.127365 -1.074975  1.448269
# 2022-01-05  0.201451  0.501756  1.613335 -1.897711  1.299083  0.553184
# 2022-01-06  0.262287  0.219070  0.932353  1.743052 -0.124704  0.954032
# 2022-01-07 -0.761819  1.661502  2.547692 -0.038912 -0.356409 -1.862569
# 2022-01-08  0.103749  0.115432  0.258670  1.487743  1.454343  0.704308
# 2022-01-09 -1.085523  0.363210 -1.813277 -0.197911  0.432875 -0.540566
# 2022-01-10 -1.842433 -0.511166 -0.580935  1.062736  0.018055  0.022798
#
#                    G         H
# 2022-01-01 -0.188846  0.211127
# 2022-01-02  1.769101  0.268200
# 2022-01-03  1.198679 -2.594654
# 2022-01-04 -0.278354 -1.036819
# ...

# %%
df
# Out:
#                    A         B         C         D         E         F  \
# 2022-01-01  1.552807 -1.149299  0.188531  0.988964 -1.586136 -0.472381
# 2022-01-02  1.611722  0.566730 -0.641177  1.538774  0.309664 -0.448849
# 2022-01-03 -1.462225  1.850810  1.700770  0.353391  0.336489  1.057105
# 2022-01-04 -0.714745  0.804346  1.191655 -0.127365 -1.074975  1.448269
# 2022-01-05  0.201451  0.501756  1.613335 -1.897711  1.299083  0.553184
# 2022-01-06  0.262287  0.219070  0.932353  1.743052 -0.124704  0.954032
# 2022-01-07 -0.761819  1.661502  2.547692 -0.038912 -0.356409 -1.862569
# 2022-01-08  0.103749  0.115432  0.258670  1.487743  1.454343  0.704308
# 2022-01-09 -1.085523  0.363210 -1.813277 -0.197911  0.432875 -0.540566
# 2022-01-10 -1.842433 -0.511166 -0.580935  1.062736  0.018055  0.022798
#
#                    G         H
# 2022-01-01 -0.188846  0.211127
# 2022-01-02  1.769101  0.268200
# 2022-01-03  1.198679 -2.594654
# 2022-01-04 -0.278354 -1.036819
# ...

# %% [markdown]
# ### Select by labels

# %%
df.loc[tarekh[0]] # by using loc funtion, we can index framing / selection of index
# Out:
# A    1.552807
# B   -1.149299
# C    0.188531
# D    0.988964
# E   -1.586136
# F   -0.472381
# G   -0.188846
# H    0.211127
# Name: 2022-01-01 00:00:00, dtype: float64

# %% [markdown]
# ##### Row wise selection

# %%
df.loc[tarekh[1]] # here the data is showing row wise
# Out:
# A    1.611722
# B    0.566730
# C   -0.641177
# D    1.538774
# E    0.309664
# F   -0.448849
# G    1.769101
# H    0.268200
# Name: 2022-01-02 00:00:00, dtype: float64

# %%
df.loc[tarekh[9]]
# Out:
# A   -1.842433
# B   -0.511166
# C   -0.580935
# D    1.062736
# E    0.018055
# F    0.022798
# G   -1.679791
# H    0.812423
# Name: 2022-01-10 00:00:00, dtype: float64

# %%
df
# Out:
#                    A         B         C         D         E         F  \
# 2022-01-01  1.552807 -1.149299  0.188531  0.988964 -1.586136 -0.472381
# 2022-01-02  1.611722  0.566730 -0.641177  1.538774  0.309664 -0.448849
# 2022-01-03 -1.462225  1.850810  1.700770  0.353391  0.336489  1.057105
# 2022-01-04 -0.714745  0.804346  1.191655 -0.127365 -1.074975  1.448269
# 2022-01-05  0.201451  0.501756  1.613335 -1.897711  1.299083  0.553184
# 2022-01-06  0.262287  0.219070  0.932353  1.743052 -0.124704  0.954032
# 2022-01-07 -0.761819  1.661502  2.547692 -0.038912 -0.356409 -1.862569
# 2022-01-08  0.103749  0.115432  0.258670  1.487743  1.454343  0.704308
# 2022-01-09 -1.085523  0.363210 -1.813277 -0.197911  0.432875 -0.540566
# 2022-01-10 -1.842433 -0.511166 -0.580935  1.062736  0.018055  0.022798
#
#                    G         H
# 2022-01-01 -0.188846  0.211127
# 2022-01-02  1.769101  0.268200
# 2022-01-03  1.198679 -2.594654
# 2022-01-04 -0.278354 -1.036819
# ...

# %% [markdown]
# ##### Column wise selection:

# %%
## Multiple axis lables

df.loc[:, ["A","D"]] # here the 1st part of : is rows and 2nd part of ["A","B"] are columns
# Out:
#                    A         D
# 2022-01-01  1.552807  0.988964
# 2022-01-02  1.611722  1.538774
# 2022-01-03 -1.462225  0.353391
# 2022-01-04 -0.714745 -0.127365
# 2022-01-05  0.201451 -1.897711
# 2022-01-06  0.262287  1.743052
# 2022-01-07 -0.761819 -0.038912
# 2022-01-08  0.103749  1.487743
# 2022-01-09 -1.085523 -0.197911
# 2022-01-10 -1.842433  1.062736

# %%
df.loc[:, ["B","A"]]
# Out:
#                    B         A
# 2022-01-01 -1.149299  1.552807
# 2022-01-02  0.566730  1.611722
# 2022-01-03  1.850810 -1.462225
# 2022-01-04  0.804346 -0.714745
# 2022-01-05  0.501756  0.201451
# 2022-01-06  0.219070  0.262287
# 2022-01-07  1.661502 -0.761819
# 2022-01-08  0.115432  0.103749
# 2022-01-09  0.363210 -1.085523
# 2022-01-10 -0.511166 -1.842433

# %% [markdown]
# ### Specific dates data

# %%
df.loc["20220101":"20220110",["C","D"]]
# Out:
#                    C         D
# 2022-01-01  0.188531  0.988964
# 2022-01-02 -0.641177  1.538774
# 2022-01-03  1.700770  0.353391
# 2022-01-04  1.191655 -0.127365
# 2022-01-05  1.613335 -1.897711
# 2022-01-06  0.932353  1.743052
# 2022-01-07  2.547692 -0.038912
# 2022-01-08  0.258670  1.487743
# 2022-01-09 -1.813277 -0.197911
# 2022-01-10 -0.580935  1.062736

# %%
df.loc["20220101":"20220104",["A","D"]] # so here is a difference if we are using {":"} then it will show the data from 2022-01-01 to 2022-01-04
# Out:
#                    A         D
# 2022-01-01  1.552807  0.988964
# 2022-01-02  1.611722  1.538774
# 2022-01-03 -1.462225  0.353391
# 2022-01-04 -0.714745 -0.127365

# %%
df.loc[["20220101","20220109"],["D","E","G"]] # we can only show the specified values.
# Out:
#                    D         E         G
# 2022-01-01  0.988964 -1.586136 -0.188846
# 2022-01-09 -0.197911  0.432875  0.295631

# %%
df.loc[["20220104","20220106"],["D","E","F"]]
# Out:
#                    D         E         F
# 2022-01-04 -0.127365 -1.074975  1.448269
# 2022-01-06  1.743052 -0.124704  0.954032

# %%
df.loc["20220105",["A","B","C","D"]]
# Out:
# A    0.201451
# B    0.501756
# C    1.613335
# D   -1.897711
# Name: 2022-01-05 00:00:00, dtype: float64

# %%
df
# Out:
#                    A         B         C         D         E         F  \
# 2022-01-01  1.552807 -1.149299  0.188531  0.988964 -1.586136 -0.472381
# 2022-01-02  1.611722  0.566730 -0.641177  1.538774  0.309664 -0.448849
# 2022-01-03 -1.462225  1.850810  1.700770  0.353391  0.336489  1.057105
# 2022-01-04 -0.714745  0.804346  1.191655 -0.127365 -1.074975  1.448269
# 2022-01-05  0.201451  0.501756  1.613335 -1.897711  1.299083  0.553184
# 2022-01-06  0.262287  0.219070  0.932353  1.743052 -0.124704  0.954032
# 2022-01-07 -0.761819  1.661502  2.547692 -0.038912 -0.356409 -1.862569
# 2022-01-08  0.103749  0.115432  0.258670  1.487743  1.454343  0.704308
# 2022-01-09 -1.085523  0.363210 -1.813277 -0.197911  0.432875 -0.540566
# 2022-01-10 -1.842433 -0.511166 -0.580935  1.062736  0.018055  0.022798
#
#                    G         H
# 2022-01-01 -0.188846  0.211127
# 2022-01-02  1.769101  0.268200
# 2022-01-03  1.198679 -2.594654
# 2022-01-04 -0.278354 -1.036819
# ...

# %%
df.at[tarekh[5],"A"]
# Out:
# 0.26228661897316985

# %%
df.at[tarekh[0],"H"]
# Out:
# 0.21112708032840474

# %%
df.iloc[0:5]
# Out:
#                    A         B         C         D         E         F  \
# 2022-01-01  1.552807 -1.149299  0.188531  0.988964 -1.586136 -0.472381
# 2022-01-02  1.611722  0.566730 -0.641177  1.538774  0.309664 -0.448849
# 2022-01-03 -1.462225  1.850810  1.700770  0.353391  0.336489  1.057105
# 2022-01-04 -0.714745  0.804346  1.191655 -0.127365 -1.074975  1.448269
# 2022-01-05  0.201451  0.501756  1.613335 -1.897711  1.299083  0.553184
#
#                    G         H
# 2022-01-01 -0.188846  0.211127
# 2022-01-02  1.769101  0.268200
# 2022-01-03  1.198679 -2.594654
# 2022-01-04 -0.278354 -1.036819
# 2022-01-05 -0.200362  0.545670

# %%
df.iloc[5:]
# Out:
#                    A         B         C         D         E         F  \
# 2022-01-06  0.262287  0.219070  0.932353  1.743052 -0.124704  0.954032
# 2022-01-07 -0.761819  1.661502  2.547692 -0.038912 -0.356409 -1.862569
# 2022-01-08  0.103749  0.115432  0.258670  1.487743  1.454343  0.704308
# 2022-01-09 -1.085523  0.363210 -1.813277 -0.197911  0.432875 -0.540566
# 2022-01-10 -1.842433 -0.511166 -0.580935  1.062736  0.018055  0.022798
#
#                    G         H
# 2022-01-06  0.712051 -0.579337
# 2022-01-07  2.651999 -0.136230
# 2022-01-08  1.466351  0.353622
# 2022-01-09  0.295631  2.079844
# 2022-01-10 -1.679791  0.812423

# %%
df.iloc[0:3,5:8] # 0:3 is the rows and 5:8 are columns
# Out:
#                    F         G         H
# 2022-01-01 -0.472381 -0.188846  0.211127
# 2022-01-02 -0.448849  1.769101  0.268200
# 2022-01-03  1.057105  1.198679 -2.594654

# %%
df.iloc[0:,0:]
# Out:
#                    A         B         C         D         E         F  \
# 2022-01-01  1.552807 -1.149299  0.188531  0.988964 -1.586136 -0.472381
# 2022-01-02  1.611722  0.566730 -0.641177  1.538774  0.309664 -0.448849
# 2022-01-03 -1.462225  1.850810  1.700770  0.353391  0.336489  1.057105
# 2022-01-04 -0.714745  0.804346  1.191655 -0.127365 -1.074975  1.448269
# 2022-01-05  0.201451  0.501756  1.613335 -1.897711  1.299083  0.553184
# 2022-01-06  0.262287  0.219070  0.932353  1.743052 -0.124704  0.954032
# 2022-01-07 -0.761819  1.661502  2.547692 -0.038912 -0.356409 -1.862569
# 2022-01-08  0.103749  0.115432  0.258670  1.487743  1.454343  0.704308
# 2022-01-09 -1.085523  0.363210 -1.813277 -0.197911  0.432875 -0.540566
# 2022-01-10 -1.842433 -0.511166 -0.580935  1.062736  0.018055  0.022798
#
#                    G         H
# 2022-01-01 -0.188846  0.211127
# 2022-01-02  1.769101  0.268200
# 2022-01-03  1.198679 -2.594654
# 2022-01-04 -0.278354 -1.036819
# ...

# %%
# if we need to mention only columns then:

df.iloc[:,5:7]
# Out:
#                    F         G
# 2022-01-01 -0.472381 -0.188846
# 2022-01-02 -0.448849  1.769101
# 2022-01-03  1.057105  1.198679
# 2022-01-04  1.448269 -0.278354
# 2022-01-05  0.553184 -0.200362
# 2022-01-06  0.954032  0.712051
# 2022-01-07 -1.862569  2.651999
# 2022-01-08  0.704308  1.466351
# 2022-01-09 -0.540566  0.295631
# 2022-01-10  0.022798 -1.679791

# %% [markdown]
# # Booleans

# %%
df[df["G"]>1.9]
# Out:
#                    A         B         C         D         E         F  \
# 2022-01-07 -0.761819  1.661502  2.547692 -0.038912 -0.356409 -1.862569
#
#                    G        H
# 2022-01-07  2.651999 -0.13623

# %%
df[df["H"]>2]
# Out:
#                    A        B         C         D         E         F  \
# 2022-01-09 -1.085523  0.36321 -1.813277 -0.197911  0.432875 -0.540566
#
#                    G         H
# 2022-01-09  0.295631  2.079844

# %%
df[df>=2.5]
# Out:
#              A   B         C   D   E   F         G   H
# 2022-01-01 NaN NaN       NaN NaN NaN NaN       NaN NaN
# 2022-01-02 NaN NaN       NaN NaN NaN NaN       NaN NaN
# 2022-01-03 NaN NaN       NaN NaN NaN NaN       NaN NaN
# 2022-01-04 NaN NaN       NaN NaN NaN NaN       NaN NaN
# 2022-01-05 NaN NaN       NaN NaN NaN NaN       NaN NaN
# 2022-01-06 NaN NaN       NaN NaN NaN NaN       NaN NaN
# 2022-01-07 NaN NaN  2.547692 NaN NaN NaN  2.651999 NaN
# 2022-01-08 NaN NaN       NaN NaN NaN NaN       NaN NaN
# 2022-01-09 NaN NaN       NaN NaN NaN NaN       NaN NaN
# 2022-01-10 NaN NaN       NaN NaN NaN NaN       NaN NaN

# %% [markdown]
# ## Making a Copy of dataset

# %%
df3=df.copy()
df3
# Out:
#                    A         B         C         D         E         F  \
# 2022-01-01  1.552807 -1.149299  0.188531  0.988964 -1.586136 -0.472381
# 2022-01-02  1.611722  0.566730 -0.641177  1.538774  0.309664 -0.448849
# 2022-01-03 -1.462225  1.850810  1.700770  0.353391  0.336489  1.057105
# 2022-01-04 -0.714745  0.804346  1.191655 -0.127365 -1.074975  1.448269
# 2022-01-05  0.201451  0.501756  1.613335 -1.897711  1.299083  0.553184
# 2022-01-06  0.262287  0.219070  0.932353  1.743052 -0.124704  0.954032
# 2022-01-07 -0.761819  1.661502  2.547692 -0.038912 -0.356409 -1.862569
# 2022-01-08  0.103749  0.115432  0.258670  1.487743  1.454343  0.704308
# 2022-01-09 -1.085523  0.363210 -1.813277 -0.197911  0.432875 -0.540566
# 2022-01-10 -1.842433 -0.511166 -0.580935  1.062736  0.018055  0.022798
#
#                    G         H
# 2022-01-01 -0.188846  0.211127
# 2022-01-02  1.769101  0.268200
# 2022-01-03  1.198679 -2.594654
# 2022-01-04 -0.278354 -1.036819
# ...

# %% [markdown]
# ### Addition of a column

# %%
# addition of a column in a dataset
df3["I"]=["one","two","three","four","five","six","7","8","9","10"]
df3
# Out:
#                    A         B         C         D         E         F  \
# 2022-01-01  1.552807 -1.149299  0.188531  0.988964 -1.586136 -0.472381
# 2022-01-02  1.611722  0.566730 -0.641177  1.538774  0.309664 -0.448849
# 2022-01-03 -1.462225  1.850810  1.700770  0.353391  0.336489  1.057105
# 2022-01-04 -0.714745  0.804346  1.191655 -0.127365 -1.074975  1.448269
# 2022-01-05  0.201451  0.501756  1.613335 -1.897711  1.299083  0.553184
# 2022-01-06  0.262287  0.219070  0.932353  1.743052 -0.124704  0.954032
# 2022-01-07 -0.761819  1.661502  2.547692 -0.038912 -0.356409 -1.862569
# 2022-01-08  0.103749  0.115432  0.258670  1.487743  1.454343  0.704308
# 2022-01-09 -1.085523  0.363210 -1.813277 -0.197911  0.432875 -0.540566
# 2022-01-10 -1.842433 -0.511166 -0.580935  1.062736  0.018055  0.022798
#
#                    G         H      I
# 2022-01-01 -0.188846  0.211127    one
# 2022-01-02  1.769101  0.268200    two
# 2022-01-03  1.198679 -2.594654  three
# ...

# %%
df3["New_Column"]=["02","03","04","05","06","07","08","09","10","11"]
df3
# Out:
#                    A         B         C         D         E         F  \
# 2022-01-01  1.552807 -1.149299  0.188531  0.988964 -1.586136 -0.472381
# 2022-01-02  1.611722  0.566730 -0.641177  1.538774  0.309664 -0.448849
# 2022-01-03 -1.462225  1.850810  1.700770  0.353391  0.336489  1.057105
# 2022-01-04 -0.714745  0.804346  1.191655 -0.127365 -1.074975  1.448269
# 2022-01-05  0.201451  0.501756  1.613335 -1.897711  1.299083  0.553184
# 2022-01-06  0.262287  0.219070  0.932353  1.743052 -0.124704  0.954032
# 2022-01-07 -0.761819  1.661502  2.547692 -0.038912 -0.356409 -1.862569
# 2022-01-08  0.103749  0.115432  0.258670  1.487743  1.454343  0.704308
# 2022-01-09 -1.085523  0.363210 -1.813277 -0.197911  0.432875 -0.540566
# 2022-01-10 -1.842433 -0.511166 -0.580935  1.062736  0.018055  0.022798
#
#                    G         H      I New_Column
# 2022-01-01 -0.188846  0.211127    one         02
# 2022-01-02  1.769101  0.268200    two         03
# ...

# %%
# updating the data, by remving the Naya_Column

df3=df3.iloc[:,1:6]
df3
# Out:
#                    B         C         D         E         F
# 2022-01-01 -1.149299  0.188531  0.988964 -1.586136 -0.472381
# 2022-01-02  0.566730 -0.641177  1.538774  0.309664 -0.448849
# 2022-01-03  1.850810  1.700770  0.353391  0.336489  1.057105
# 2022-01-04  0.804346  1.191655 -0.127365 -1.074975  1.448269
# 2022-01-05  0.501756  1.613335 -1.897711  1.299083  0.553184
# 2022-01-06  0.219070  0.932353  1.743052 -0.124704  0.954032
# 2022-01-07  1.661502  2.547692 -0.038912 -0.356409 -1.862569
# 2022-01-08  0.115432  0.258670  1.487743  1.454343  0.704308
# 2022-01-09  0.363210 -1.813277 -0.197911  0.432875 -0.540566
# 2022-01-10 -0.511166 -0.580935  1.062736  0.018055  0.022798

# %% [markdown]
# ## Practice from documentation

# %%
df = pd.DataFrame({
    'sales': [3, 2, 3, 9, 10, 6],
    'signups': [5, 5, 6, 12, 14, 13],
    'visits': [20, 42, 28, 62, 81, 50],
}, index=pd.date_range(start='2018/01/01', end='2018/07/01',
                       freq='M'))
ax = df.plot.area()

# %%
ax = df.plot.area(stacked=False)

# %%
speed = [0.1, 17.5, 40, 48, 52, 69, 88]
lifespan = [2, 8, 70, 1.5, 25, 12, 28]
index = ['snail', 'pig', 'elephant',
         'rabbit', 'giraffe', 'coyote', 'horse']
df = pd.DataFrame({'speed': speed,
                   'lifespan': lifespan}, index=index)
ax = df.plot.bar(rot=0)

# %%
df = pd.DataFrame({
    'x': [1, 2, 2.5, 3, 3.5, 4, 5],
    'y': [4, 4, 4.5, 5, 5.5, 6, 6],
})
ax = df.plot.kde()

# %%
ax = df.plot.kde(ind=[1, 2, 3, 4, 5, 6])

# %%
n = 10000
df = pd.DataFrame({'x': np.random.randn(n),
                   'y': np.random.randn(n)})
ax = df.plot.hexbin(x='x', y='y', gridsize=20)

# %%
n = 500
df = pd.DataFrame({
    'coord_x': np.random.uniform(-3, 3, size=n),
    'coord_y': np.random.uniform(30, 50, size=n),
    'observations': np.random.randint(1,5, size=n)
    })
ax = df.plot.hexbin(x='coord_x',
                    y='coord_y',
                    C='observations',
                    reduce_C_function=np.sum,
                    gridsize=10,
                    cmap="viridis")

# %%
df = pd.DataFrame(
    np.random.randint(1, 7, 6000),
    columns = ['one'])
df['two'] = df['one'] + np.random.randint(1, 7, 6000)
ax = df.plot.hist(bins=12, alpha=0.5)

# %%
age_list = [8, 10, 12, 14, 72, 74, 76, 78, 20, 25, 30, 35, 60, 85]
df = pd.DataFrame({"gender": list("MMMMMMMMFFFFFF"), "age": age_list})
ax = df.plot.hist(column=["age"], by="gender", figsize=(10, 8))

# %%
df = pd.DataFrame({'mass': [0.330, 4.87 , 5.97],
                   'radius': [2439.7, 6051.8, 6378.1]},
                  index=['Mercury', 'Venus', 'Earth'])
plot = df.plot.pie(y='mass', figsize=(5, 5))

# %%
plot = df.plot.pie(subplots=True, figsize=(11, 6))

# %%
df = pd.DataFrame([[5.1, 3.5, 0], [4.9, 3.0, 0], [7.0, 3.2, 1],
                   [6.4, 3.2, 1], [5.9, 3.0, 2]],
                  columns=['length', 'width', 'species'])
ax1 = df.plot.scatter(x='length',
                      y='width',
                      c='DarkBlue')

# %%
ax2 = df.plot.scatter(x='length',
                      y='width',
                      c='species',
                      colormap='viridis')

# %%
df = pd.DataFrame({
    'length': [1.5, 0.5, 1.2, 0.9, 3],
    'width': [0.7, 0.2, 0.15, 0.2, 1.1]
    }, index=['pig', 'rabbit', 'duck', 'chicken', 'horse'])
hist = df.hist(bins=3)

# %%
np.random.seed(1234)
df = pd.DataFrame(np.random.randn(10, 4),
                  columns=['Col1', 'Col2', 'Col3', 'Col4'])
boxplot = df.boxplot(column=['Col1', 'Col2', 'Col3'])

# %%
df = pd.DataFrame(np.random.randn(10, 3),
                  columns=['Col1', 'Col2', 'Col3'])
df['X'] = pd.Series(['A', 'A', 'A', 'A', 'A',
                     'B', 'B', 'B', 'B', 'B'])
df['Y'] = pd.Series(['A', 'B', 'A', 'B', 'A',
                     'B', 'A', 'B', 'A', 'B'])
boxplot = df.boxplot(column=['Col1', 'Col2'], by=['X', 'Y'])
